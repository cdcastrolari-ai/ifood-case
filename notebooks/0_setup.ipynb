# %% [markdown]
# ### Criar e organizar a estrutura

# %%
# %sql
-- Arquitetura: Estrutura de armazenamento
CREATE SCHEMA IF NOT EXISTS workspace.raw;
CREATE VOLUME IF NOT EXISTS workspace.raw.ifood_case;
CREATE SCHEMA IF NOT EXISTS main.gold; -- Schema para camada de dados prontos

# %%
# Estrutura de pastas
for path in [
    "/Workspace/ifood-case/data/raw", #Pasta com dados brutos
]:
    dbutils.fs.mkdirs(path)
